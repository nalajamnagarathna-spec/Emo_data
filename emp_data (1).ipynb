# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("Emp_data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Emp_ID        10 non-null     int64
#  1   Name          9 non-null      object
#  2   Gender        10 non-null     object
#  3   Department    10 non-null     object
#  4   Salary        9 non-null      float64
#  5   Joining_Date  9 non-null      datetime64[ns]
#  6   Email         8 non-null      object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 692.0+ bytes

# %%
df.head()
# Out:
#    Emp_ID          Name  Gender Department   Salary Joining_Date  \
# 0     101    Ravi Kumar    Male         HR  45000.0   2024-01-15
# 1     102  Priya Sharma  Female         IT  55000.0   2024-02-15
# 2     103   Rahul Singh       M    Finance      NaN   2024-03-10
# 3     104   Sneha Reddy       F         HR  48000.0          NaT
# 4     105   Arjun Patel    Male         IT  60000.0   2024-04-20
#
#              Email
# 0   ravi@gmail.com
# 1  priya@gmail.com
# 2  rahul@gmail.com
# 3  sneha@gmail.com
# 4              NaN

# %%
df.isnull().sum()
# Out:
# Emp_ID          0
# Name            1
# Gender          0
# Department      0
# Salary          1
# Joining_Date    1
# Email           2
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    Emp_ID         Name Gender Department   Salary Joining_Date Email
# 5     105  Arjun Patel   Male         IT  60000.0   2024-04-20   NaN

# %%
df.replace("NULL",np.nan,inplace=True)

# %%
df["Gender"]=df["Gender"].replace({
    "M":"Male",
    "F":"Female",
    "FEMALE":"Female",
    "male":"Male"
})

# %%
df["Department"]=df["Department"].str.title()

# %%
df["Name"]=df["Name"].str.title()

# %%
df.drop_duplicates(inplace=True)

# %%
df["Name"]= df["Name"]. fillna("Unknown")
df["Email"]=df["Email"]. fillna("Not Available")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Emp_ID        9 non-null      int64
#  1   Name          9 non-null      object
#  2   Gender        9 non-null      object
#  3   Department    9 non-null      object
#  4   Salary        9 non-null      float64
#  5   Joining_Date  8 non-null      datetime64[ns]
#  6   Email         9 non-null      object
#  7   Joining_Data  9 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 648.0+ bytes

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["Salary"].dtype
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#    Emp_ID          Name  Gender Department   Salary Joining_Date  \
# 0     101    Ravi Kumar    Male         Hr  45000.0   2024-01-15
# 1     102  Priya Sharma  Female         It  55000.0   2024-02-15
# 2     103   Rahul Singh    Male    Finance      0.0   2024-03-10
# 3     104   Sneha Reddy  Female         Hr  48000.0          NaT
# 4     105   Arjun Patel    Male         It  60000.0   2024-04-20
#
#              Email
# 0   ravi@gmail.com
# 1  priya@gmail.com
# 2  rahul@gmail.com
# 3  sneha@gmail.com
# 4      Unavailable

# %%
df["Salary"]=df["Salary"].fillna(0)

# %%
df.head()
# Out:
#    Emp_ID          Name  Gender Department   Salary Joining_Date  \
# 0     101    Ravi Kumar    Male         Hr  45000.0   2024-01-15
# 1     102  Priya Sharma  Female         It  55000.0   2024-02-15
# 2     103   Rahul Singh    Male    Finance      0.0   2024-03-10
# 3     104   Sneha Reddy  Female         Hr  48000.0          NaT
# 4     105   Arjun Patel    Male         It  60000.0   2024-04-20
#
#              Email
# 0   ravi@gmail.com
# 1  priya@gmail.com
# 2  rahul@gmail.com
# 3  sneha@gmail.com
# 4      Unavailable

# %%
df["Joining_Data"]=df["Joining_Date"].fillna(pd.Timestamp("24-09-2026"))

# %%
df.head()
# Out:
#    Emp_ID          Name  Gender Department   Salary Joining_Date  \
# 0     101    Ravi Kumar    Male         Hr  45000.0   2024-01-15
# 1     102  Priya Sharma  Female         It  55000.0   2024-02-15
# 2     103   Rahul Singh    Male    Finance      0.0   2024-03-10
# 3     104   Sneha Reddy  Female         Hr  48000.0          NaT
# 4     105   Arjun Patel    Male         It  60000.0   2024-04-20
#
#              Email Joining_Data
# 0   ravi@gmail.com   2024-01-15
# 1  priya@gmail.com   2024-02-15
# 2  rahul@gmail.com   2024-03-10
# 3  sneha@gmail.com   2026-09-24
# 4      Unavailable   2024-04-20

# %%
df["Joining_Date"].head(10)
# Out:
# 0   2024-01-15
# 1   2024-02-15
# 2   2024-03-10
# 3          NaT
# 4   2024-04-20
# 6   2024-05-05
# 7   2024-06-01
# 8   2024-07-15
# 9   2024-08-10
# Name: Joining_Date, dtype: datetime64[ns]

# %%
df["Joining_Date"]=df["Joining_Date"].fillna("2024-04-20")

# %%
df.head()
# Out:
#    Emp_ID          Name  Gender Department   Salary Joining_Date  \
# 0     101    Ravi Kumar    Male         Hr  45000.0   2024-01-15
# 1     102  Priya Sharma  Female         It  55000.0   2024-02-15
# 2     103   Rahul Singh    Male    Finance      0.0   2024-03-10
# 3     104   Sneha Reddy  Female         Hr  48000.0   2024-04-20
# 4     105   Arjun Patel    Male         It  60000.0   2024-04-20
#
#              Email Joining_Data
# 0   ravi@gmail.com   2024-01-15
# 1  priya@gmail.com   2024-02-15
# 2  rahul@gmail.com   2024-03-10
# 3  sneha@gmail.com   2026-09-24
# 4      Unavailable   2024-04-20

# %%
df.isnull().sum()
# Out:
# Emp_ID          0
# Name            0
# Gender          0
# Department      0
# Salary          0
# Joining_Date    0
# Email           0
# Joining_Data    0
# dtype: int64

# %%
df.describe()
# Out:
#            Emp_ID        Salary         Joining_Date         Joining_Data
# count    9.000000      9.000000                    9                    9
# mean   105.000000  45444.444444  2024-04-25 21:20:00  2024-08-02 10:40:00
# min    101.000000      0.000000  2024-01-15 00:00:00  2024-01-15 00:00:00
# 25%    103.000000  47000.000000  2024-03-10 00:00:00  2024-03-10 00:00:00
# 50%    105.000000  49000.000000  2024-04-20 00:00:00  2024-05-05 00:00:00
# 75%    107.000000  53000.000000  2024-06-01 00:00:00  2024-07-15 00:00:00
# max    109.000000  60000.000000  2024-08-10 00:00:00  2026-09-24 00:00:00
# std      2.738613  17643.065997                  NaN                  NaN

# %%
df["Department"].value_counts()
# Out:
# Department
# Hr         3
# It         2
# Finance    2
# Sales      2
# Name: count, dtype: int64

# %%
df["Salary"].max()
# Out:
# 60000.0

# %%
df["Salary"].min()
# Out:
# 0.0

# %%
df["Salary"].mean()
# Out:
# 45444.444444444445

# %%
df.sort_values(by="Salary",ascending=False)
# Out:
#    Emp_ID          Name  Gender Department   Salary Joining_Date  \
# 4     105   Arjun Patel    Male         It  60000.0   2024-04-20
# 1     102  Priya Sharma  Female         It  55000.0   2024-02-15
# 8     108    Meena Devi  Female    Finance  53000.0   2024-07-15
# 6     106         Kavya  Female      Sales  52000.0   2024-05-05
# 9     109       unknown  Female         Hr  49000.0   2024-08-10
# 3     104   Sneha Reddy  Female         Hr  48000.0   2024-04-20
# 7     107    Anil Kumar    Male      Sales  47000.0   2024-06-01
# 0     101    Ravi Kumar    Male         Hr  45000.0   2024-01-15
# 2     103   Rahul Singh    Male    Finance      0.0   2024-03-10
#
#              Email Joining_Data
# 4      Unavailable   2024-04-20
# 1  priya@gmail.com   2024-02-15
# 8  meena@gmail.com   2024-07-15
# 6  kavya@gmail.com   2024-05-05
# 9  hr109@gmail.com   2024-08-10
# 3  sneha@gmail.com   2026-09-24
# 7   anil@gmail.com   2024-06-01
# 0   ravi@gmail.com   2024-01-15
# ...

# %%
df[df["Department"]=="Hr"]
# Out:
#    Emp_ID         Name  Gender Department   Salary Joining_Date  \
# 0     101   Ravi Kumar    Male         Hr  45000.0   2024-01-15
# 3     104  Sneha Reddy       F         Hr  48000.0          NaT
# 9     109      Unknown  Female         Hr  49000.0   2024-08-10
#
#              Email Joining_Data
# 0   ravi@gmail.com   2024-01-15
# 3  sneha@gmail.com   2026-09-24
# 9  hr109@gmail.com   2024-08-10

# %%
df.to_excel("Emp_data_cleaned.xlsx", index=False)

# %%
plt.figure(figsize=(5,6))
plt.bar(df["Name"],df["Salary"])
plt.title("employee salary")
plt.xlabel("Employee Name")
plt.ylabel("Salary")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(5,6))
plt.boxplot(df["Salary"])
plt.title("Salary Box Plot")
plt.ylabel("Salary")
plt.show()

# %%
dept=df["Department"].value_counts()
plt.figure(figsize=(6,6))
plt.pie (dept,labels=dept.index, autopct="%1.1f%%")
plt.title("Department Distribution")
plt.show()
